# %%
#Importing libraries
import pandas as pd
import numpy as np
import json
import os
import pymysql
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import plotly.express as px
import plotly.io as pio
import nbformat
print(nbformat.__version__)
from sqlalchemy import create_engine
import sqlalchemy
# Out:
# 5.10.4

# %%
from sqlalchemy import create_engine
import sqlalchemy

# %%
#AGGREGATED - TRANSACTION DATA
#This is to direct the path to get the data as states
path="C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/data/aggregated/transaction/country/india/state/"
#Agg_state_list--> to get the list of states in India
Agg_state_list=os.listdir(path)
Agg_state_list

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transaction_type'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Created a dataframe
aggregated_transaction=pd.DataFrame(clm)
aggregated_transaction
# Out:
#                           State  Year  Quater          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018       1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018       1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018       1         Merchant payments
# 3     andaman-&-nicobar-islands  2018       1        Financial Services
# 4     andaman-&-nicobar-islands  2018       1                    Others
# ...                         ...   ...     ...                       ...
# 5029                west-bengal  2024       4         Merchant payments
# 5030                west-bengal  2024       4     Peer-to-peer payments
# 5031                west-bengal  2024       4  Recharge & bill payments
# 5032                west-bengal  2024       4        Financial Services
# 5033                west-bengal  2024       4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
#AGGREGATED - INSURANCE 
#This is to direct the path to get the data as states
path="C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/data/aggregated/insurance/country/india/state/"

#Agg_state_list--> to get the list of states in India
Agg_state_list=os.listdir(path)
Agg_state_list

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quater':[],'Payment_type':[], 'Insurance_count':[], 'Insurance_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Payment_type'].append(Name)
              clm['Insurance_count'].append(count)
              clm['Insurance_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Created a dataframe
aggregated_insurance=pd.DataFrame(clm)
aggregated_insurance
# Out:
#                          State  Year  Quater Payment_type  Insurance_count  \
# 0    andaman-&-nicobar-islands  2020       2    Insurance                6
# 1    andaman-&-nicobar-islands  2020       3    Insurance               41
# 2    andaman-&-nicobar-islands  2020       4    Insurance              124
# 3    andaman-&-nicobar-islands  2021       1    Insurance              225
# 4    andaman-&-nicobar-islands  2021       2    Insurance              137
# ..                         ...   ...     ...          ...              ...
# 677                west-bengal  2023       4    Insurance            72712
# 678                west-bengal  2024       1    Insurance            79576
# 679                west-bengal  2024       2    Insurance            67048
# 680                west-bengal  2024       3    Insurance            77158
# 681                west-bengal  2024       4    Insurance            91719
#
#      Insurance_amount
# 0              1360.0
# ...

# %%
#AGGREGATED - USERS 
#This is to direct the path to get the data as states
path="C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/data/aggregated/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Users_brand':[], 'Users_count':[], 'Users_percentage':[], 'RegisteredUsers':[], 'AppOpens':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            aggregated_data = D.get('data', {}).get('aggregated', {})
            registeredUsers = aggregated_data.get('registeredUsers', 0)
            appOpens = aggregated_data.get('appOpens', 0)

            if D['data'].get('usersByDevice') is not None:
              for z in D['data']['usersByDevice']:
                brand = z.get('brand', 'Unknown')
                count = z.get('count', 0)
                percentage = z.get('percentage', 0.0)
                clm['Users_brand'].append(brand)
                clm['Users_count'].append(count)
                clm['Users_percentage'].append(percentage)
                clm['RegisteredUsers'].append(registeredUsers)
                clm['AppOpens'].append(appOpens)

                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quater'].append(int(k.strip('.json')))
#Created a dataframe
aggregated_users=pd.DataFrame(clm)
aggregated_users
# Out:
#                           State  Year  Quater Users_brand  Users_count  \
# 0     andaman-&-nicobar-islands  2018       1      Xiaomi         1665
# 1     andaman-&-nicobar-islands  2018       1     Samsung         1445
# 2     andaman-&-nicobar-islands  2018       1        Vivo          982
# 3     andaman-&-nicobar-islands  2018       1        Oppo          501
# 4     andaman-&-nicobar-islands  2018       1     OnePlus          332
# ...                         ...   ...     ...         ...          ...
# 6727                west-bengal  2022       1      Lenovo       330017
# 6728                west-bengal  2022       1     Infinix       284678
# 6729                west-bengal  2022       1        Asus       280347
# 6730                west-bengal  2022       1       Apple       277752
# 6731                west-bengal  2022       1      Others      2196334
#
#       Users_percentage  RegisteredUsers   AppOpens
# 0             0.247033             6740          0
# ...

# %%
#MAP - TRANSACTION HOVER 
#This is to direct the path to get the data as states
path="C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/data/map/transaction/hover/country/india/state/"

#Agg_state_list--> to get the list of states in India

Agg_state_list=os.listdir(path)
Agg_state_list


#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Transaction_Hover_name':[], 'Transaction_Hover_count':[], 'Transaction_Hover_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Transaction_Hover_name'].append(Name)
              clm['Transaction_Hover_count'].append(count)
              clm['Transaction_Hover_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Created a dataframe
map_transaction_hover=pd.DataFrame(clm)
map_transaction_hover
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 20599                west-bengal  2024       4
# 20600                west-bengal  2024       4
# 20601                west-bengal  2024       4
# 20602                west-bengal  2024       4
# 20603                west-bengal  2024       4
#
#                   Transaction_Hover_name  Transaction_Hover_count  \
# 0      north and middle andaman district                      442
# 1                 south andaman district                     5688
# 2                      nicobars district                      528
# 3      north and middle andaman district                      825
# ...

# %%
#MAP - INSURANCE HOVER 
#This is to direct the path to get the data as states
path="C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/data/map/insurance/hover/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Insurance_Hover_name':[], 'Insurance_Hover_count':[], 'Insurance_Hover_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Insurance_Hover_name'].append(Name)
              clm['Insurance_Hover_count'].append(count)
              clm['Insurance_Hover_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#created a dataframe
map_insurance_hover=pd.DataFrame(clm)
map_insurance_hover
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2020       2
# 1      andaman-&-nicobar-islands  2020       2
# 2      andaman-&-nicobar-islands  2020       3
# 3      andaman-&-nicobar-islands  2020       3
# 4      andaman-&-nicobar-islands  2020       3
# ...                          ...   ...     ...
# 13871                west-bengal  2024       4
# 13872                west-bengal  2024       4
# 13873                west-bengal  2024       4
# 13874                west-bengal  2024       4
# 13875                west-bengal  2024       4
#
#                     Insurance_Hover_name  Insurance_Hover_count  \
# 0                 south andaman district                      3
# 1                      nicobars district                      3
# 2      north and middle andaman district                      1
# 3                 south andaman district                     35
# 4                      nicobars district                      5
# ...

# %%
#MAP - USERS HOVER 
#This is to direct the path to get the data as states
path="C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/data/map/user/hover/country/india/state/"

#Agg_state_list--> to get the list of states in India
Agg_state_list=os.listdir(path)
Agg_state_list

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'District':[],'Registered_Users':[], 'App_Opens':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for zz,z in D['data']['hoverData'].items():
              registeredUsers=z['registeredUsers']
              appOpens=z['appOpens']
              clm['Registered_Users'].append(registeredUsers)
              clm['App_Opens'].append(appOpens)
              clm['State'].append(i)
              clm['District'].append(zz)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
# created a dataframe
map_user_hover=pd.DataFrame(clm)
map_user_hover
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 20603                west-bengal  2024       4
# 20604                west-bengal  2024       4
# 20605                west-bengal  2024       4
# 20606                west-bengal  2024       4
# 20607                west-bengal  2024       4
#
#                                 District  Registered_Users  App_Opens
# 0      north and middle andaman district               632          0
# 1                 south andaman district              5846          0
# 2                      nicobars district               262          0
# 3      north and middle andaman district               911          0
# ...

# %%
# TOP - TRANSACTION DISTRICT 
#This is to direct the path to get the data as states
path="C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/data/top/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Transaction_District':[], 'Transaction_District_count':[], 'Transaction_District_amount':[],}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:          
              District=z['entityName']
              Districtcount=z['metric']['count']
              Districtamount=z['metric']['amount']
              clm['Transaction_District'].append(District)
              clm['Transaction_District_count'].append(Districtcount)
              clm['Transaction_District_amount'].append(Districtamount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#created a dataframe
top_transaction_district=pd.DataFrame(clm)
top_transaction_district
# Out:
#                           State  Year  Quater      Transaction_District  \
# 0     andaman-&-nicobar-islands  2018       1             south andaman
# 1     andaman-&-nicobar-islands  2018       1                  nicobars
# 2     andaman-&-nicobar-islands  2018       1  north and middle andaman
# 3     andaman-&-nicobar-islands  2018       2             south andaman
# 4     andaman-&-nicobar-islands  2018       2                  nicobars
# ...                         ...   ...     ...                       ...
# 8291                west-bengal  2024       4                    howrah
# 8292                west-bengal  2024       4                     nadia
# 8293                west-bengal  2024       4                     malda
# 8294                west-bengal  2024       4                   hooghly
# 8295                west-bengal  2024       4         paschim medinipur
#
#       Transaction_District_count  Transaction_District_amount
# ...

# %%
# TOP - TRANSACTION PINCODE

#This is to direct the path to get the data as states
path="C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/data/top/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list


#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Transaction_Pincode':[], 'Transaction_Pincode_count':[], 'Transaction_Pincode_amount':[],}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['pincodes']:          
              Pincode=z['entityName']
              Pincodecount=z['metric']['count']
              Pincodeamount=z['metric']['amount']
              clm['Transaction_Pincode'].append(Pincode)
              clm['Transaction_Pincode_count'].append(Pincodecount)
              clm['Transaction_Pincode_amount'].append(Pincodeamount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#created a dataframe
top_transaction_pincode=pd.DataFrame(clm)
top_transaction_pincode
# Out:
#                           State  Year  Quater Transaction_Pincode  \
# 0     andaman-&-nicobar-islands  2018       1              744101
# 1     andaman-&-nicobar-islands  2018       1              744103
# 2     andaman-&-nicobar-islands  2018       1              744102
# 3     andaman-&-nicobar-islands  2018       1              744105
# 4     andaman-&-nicobar-islands  2018       1              744104
# ...                         ...   ...     ...                 ...
# 9994                west-bengal  2024       4              711101
# 9995                west-bengal  2024       4              700059
# 9996                west-bengal  2024       4              700039
# 9997                west-bengal  2024       4              734001
# 9998                west-bengal  2024       4              733134
#
#       Transaction_Pincode_count  Transaction_Pincode_amount
# 0                          1622                2.769298e+06
# ...

# %%
#TOP - INSURANCE DISTRICT LEVEL
#This is to direct the path to get the data as states
path="C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/data/top/insurance/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Insurance_District':[], 'Insurance_District_count':[], 'Insurance_District_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j) 
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:
              District=z['entityName']
              Districtcount=z['metric']['count']
              Districtamount=z['metric']['amount']
              clm['Insurance_District'].append(District)
              clm['Insurance_District_count'].append(Districtcount)
              clm['Insurance_District_amount'].append(Districtamount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#created a dataframe
top_insurance_district=pd.DataFrame(clm)
top_insurance_district
# Out:
#                           State  Year  Quater        Insurance_District  \
# 0     andaman-&-nicobar-islands  2020       2                  nicobars
# 1     andaman-&-nicobar-islands  2020       2             south andaman
# 2     andaman-&-nicobar-islands  2020       3             south andaman
# 3     andaman-&-nicobar-islands  2020       3                  nicobars
# 4     andaman-&-nicobar-islands  2020       3  north and middle andaman
# ...                         ...   ...     ...                       ...
# 5603                west-bengal  2024       4         paschim bardhaman
# 5604                west-bengal  2024       4         paschim medinipur
# 5605                west-bengal  2024       4                     malda
# 5606                west-bengal  2024       4                     nadia
# 5607                west-bengal  2024       4           purba bardhaman
#
#       Insurance_District_count  Insurance_District_amount
# ...

# %%
#TOP - INSURANCE PINCODE 

#This is to direct the path to get the data as states
path="C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/data/top/insurance/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'Insurance_Pincode':[], 'Insurance_Pincode_count':[], 'Insurance_Pincode_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j) 
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)            
            for z in D['data']['pincodes']:
              Pincode=z['entityName']
              Pincodecount=z['metric']['count']
              Pincodeamount=z['metric']['amount']
              clm['Insurance_Pincode'].append(Pincode)
              clm['Insurance_Pincode_count'].append(Pincodecount)
              clm['Insurance_Pincode_amount'].append(Pincodeamount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#created a dataframe
top_insurance_pincode=pd.DataFrame(clm)
top_insurance_pincode
# Out:
#                           State  Year  Quater Insurance_Pincode  \
# 0     andaman-&-nicobar-islands  2020       2            744301
# 1     andaman-&-nicobar-islands  2020       2            744104
# 2     andaman-&-nicobar-islands  2020       2            744101
# 3     andaman-&-nicobar-islands  2020       3            744112
# 4     andaman-&-nicobar-islands  2020       3            744105
# ...                         ...   ...     ...               ...
# 6663                west-bengal  2024       4            711101
# 6664                west-bengal  2024       4            700091
# 6665                west-bengal  2024       4            700150
# 6666                west-bengal  2024       4            700039
# 6667                west-bengal  2024       4            700156
#
#       Insurance_Pincode_count  Insurance_Pincode_amount
# 0                           3                     565.0
# 1                           2                     513.0
# ...

# %%
#TOP - USERS DISTRICT  
#This is to direct the path to get the data as states
path="C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/data/top/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list

#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'User_District':[], 'User_DistrictRegisteredUsers':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['districts']:
              District=z['name']
              DistrictregisteredUsers=z['registeredUsers']
              clm['User_District'].append(District)
              clm['User_DistrictRegisteredUsers'].append(DistrictregisteredUsers)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
# created a dataframe
top_user_district=pd.DataFrame(clm)
top_user_district
# Out:
#                           State  Year  Quater             User_District  \
# 0     andaman-&-nicobar-islands  2018       1             south andaman
# 1     andaman-&-nicobar-islands  2018       1  north and middle andaman
# 2     andaman-&-nicobar-islands  2018       1                  nicobars
# 3     andaman-&-nicobar-islands  2018       2             south andaman
# 4     andaman-&-nicobar-islands  2018       2  north and middle andaman
# ...                         ...   ...     ...                       ...
# 8291                west-bengal  2024       4                   hooghly
# 8292                west-bengal  2024       4                     nadia
# 8293                west-bengal  2024       4           purba medinipur
# 8294                west-bengal  2024       4         paschim medinipur
# 8295                west-bengal  2024       4         paschim bardhaman
#
#       User_DistrictRegisteredUsers
# 0                             5846
# ...

# %%
#TOP - USERS PINCODE 
#This is to direct the path to get the data as states
path="C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/data/top/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list



#This is to extract the data's to create a dataframe
clm={'State':[], 'Year':[],'Quater':[],'User_Pincode':[], 'User_PincodeRegisteredUsers':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['pincodes']:
              Pincode=z['name']
              PincoderegisteredUsers=z['registeredUsers']
              clm['User_Pincode'].append(Pincode)
              clm['User_PincodeRegisteredUsers'].append(PincoderegisteredUsers)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#created a dataframe
top_user_pincode=pd.DataFrame(clm)
top_user_pincode
# Out:
#                           State  Year  Quater User_Pincode  \
# 0     andaman-&-nicobar-islands  2018       1       744103
# 1     andaman-&-nicobar-islands  2018       1       744101
# 2     andaman-&-nicobar-islands  2018       1       744105
# 3     andaman-&-nicobar-islands  2018       1       744102
# 4     andaman-&-nicobar-islands  2018       1       744104
# ...                         ...   ...     ...          ...
# 9995                west-bengal  2024       4       733134
# 9996                west-bengal  2024       4       700059
# 9997                west-bengal  2024       4       711302
# 9998                west-bengal  2024       4       700150
# 9999                west-bengal  2024       4       711106
#
#       User_PincodeRegisteredUsers
# 0                            1608
# 1                            1108
# 2                            1075
# 3                            1006
# 4                             272
# ...                           ...
# ...

# %%
#Exporting the dtaframes to csv

aggregated_transaction.to_csv("C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/aggregated_transaction.csv",index=False)

aggregated_insurance.to_csv("C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/aggregated_insurance.csv",index=False)

aggregated_users.to_csv("C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/aggregated_users.csv",index=False)

map_transaction_hover.to_csv("C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/map_transaction_hover.csv",index=False)

map_insurance_hover.to_csv("C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/map_insurance_hover.csv",index=False)

map_user_hover.to_csv("C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/map_user_hover.csv",index=False)

top_transaction_district.to_csv("C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/top_transaction_district.csv",index=False)

top_transaction_pincode.to_csv("C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/top_transaction_pincode.csv",index=False)

top_insurance_district.to_csv("C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/top_insurance_district.csv",index=False)

top_insurance_pincode.to_csv("C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/top_insurance_pincode.csv",index=False)

top_user_district.to_csv("C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/top_user_district.csv",index=False)

top_user_pincode.to_csv("C:/Users/mosel/Documents/PYTHON/project/project_phonepe_transaction_insight/dataset/top_user_pincode.csv",index=False)

# %%
# Database connection
db_user = "root"
db_password = "root"
db_host = "127.0.0.1"
db_name = "phonepe_transaction_insights"

# Create SQLAlchemy engine
engine = create_engine(f"mysql+pymysql://{db_user}:{db_password}@{db_host}/{db_name}")

# %%
# Connect to MySQL server **without specifying a database**
engine = create_engine('mysql+mysqlconnector://root:root@localhost')

# Create a database (raw SQL)
with engine.connect() as conn:
    conn.execute(sqlalchemy.text("CREATE DATABASE IF NOT EXISTS phonepe_transaction_insights"))

# %%
# Load CSV
df1 = pd.read_csv('aggregated_transaction.csv')


# Create engine (connection to database)
engine = create_engine('mysql+mysqlconnector://root:root@localhost/phonepe_transaction_insights')

# Send DataFrame to MySQL table
df1.to_sql(name='aggregated_transaction', con=engine, if_exists='replace', index=False)
# Out:
# 5034

# %%
# Load CSV
df2 = pd.read_csv('aggregated_insurance.csv')


# Create engine (connection to database)
engine = create_engine('mysql+mysqlconnector://root:root@localhost/phonepe_transaction_insights')

# Send DataFrame to MySQL table
df2.to_sql(name='aggregated_insurance', con=engine, if_exists='replace', index=False)
# Out:
# 682

# %%
# Load CSV
df3 = pd.read_csv('aggregated_users.csv')


# Create engine (connection to database)
engine = create_engine('mysql+mysqlconnector://root:root@localhost/phonepe_transaction_insights')

# Send DataFrame to MySQL table
df3.to_sql(name='aggregated_users', con=engine, if_exists='replace', index=False)
# Out:
# 6732

# %%
# Load CSV
df4 = pd.read_csv('map_insurance_hover.csv')


# Create engine (connection to database)
engine = create_engine('mysql+mysqlconnector://root:root@localhost/phonepe_transaction_insights')

# Send DataFrame to MySQL table
df4.to_sql(name='map_insurance_hover', con=engine, if_exists='replace', index=False)
# Out:
# 13876

# %%
# Load CSV
df5 = pd.read_csv('map_transaction_hover.csv')


# Create engine (connection to database)
engine = create_engine('mysql+mysqlconnector://root:root@localhost/phonepe_transaction_insights')

# Send DataFrame to MySQL table

df5.to_sql(name='map_transaction_hover', con=engine, if_exists='replace', index=False)
# Out:
# 20604

# %%
# Load CSV
df6 = pd.read_csv('map_user_hover.csv')


# Create engine (connection to database)
engine = create_engine('mysql+mysqlconnector://root:root@localhost/phonepe_transaction_insights')

# Send DataFrame to MySQL table
df6.to_sql(name='map_user_hover', con=engine, if_exists='replace', index=False)
# Out:
# 20608

# %%
# Load CSV
df7 = pd.read_csv('top_insurance_district.csv')


# Create engine (connection to database)
engine = create_engine('mysql+mysqlconnector://root:root@localhost/phonepe_transaction_insights')

# Send DataFrame to MySQL table
df7.to_sql(name='top_insurance_district', con=engine, if_exists='replace', index=False)
# Out:
# 5608

# %%
# Load CSV
df8 = pd.read_csv('top_insurance_pincode.csv')


# Create engine (connection to database)
engine = create_engine('mysql+mysqlconnector://root:root@localhost/phonepe_transaction_insights')

# Send DataFrame to MySQL table
df8.to_sql(name='top_insurance_pincode', con=engine, if_exists='replace', index=False)
# Out:
# 6668

# %%
# Load CSV
df9 = pd.read_csv('top_transaction_district.csv')


# Create engine (connection to database)
engine = create_engine('mysql+mysqlconnector://root:root@localhost/phonepe_transaction_insights')

# Send DataFrame to MySQL table
df9.to_sql(name='top_transaction_district', con=engine, if_exists='replace', index=False)
# Out:
# 8296

# %%
# Load CSV
df10 = pd.read_csv('top_transaction_pincode.csv')


# Create engine (connection to database)
engine = create_engine('mysql+mysqlconnector://root:root@localhost/phonepe_transaction_insights')

# Send DataFrame to MySQL table
df10.to_sql(name='top_transaction_pincode', con=engine, if_exists='replace', index=False)
# Out:
# 9999

# %%
# Load CSV
df11 = pd.read_csv('top_user_district.csv')


# Create engine (connection to database)
engine = create_engine('mysql+mysqlconnector://root:root@localhost/phonepe_transaction_insights')

# Send DataFrame to MySQL table
df11.to_sql(name='top_user_district', con=engine, if_exists='replace', index=False)
# Out:
# 8296

# %%
# Load CSV
df12 = pd.read_csv('top_user_pincode.csv')


# Create engine (connection to database)
engine = create_engine('mysql+mysqlconnector://root:root@localhost/phonepe_transaction_insights')

# Send DataFrame to MySQL table
df12.to_sql(name='top_user_pincode', con=engine, if_exists='replace', index=False)
# Out:
# 10000
